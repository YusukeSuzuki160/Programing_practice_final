# %%
import numpy as np
import ICA
import matplotlib.pyplot as plt
import math
x1 = np.loadtxt('./data/dat1.txt')
x2 = np.loadtxt('./data/dat2.txt')
x1 = x1 - np.mean(x1)
x2 = x2 - np.mean(x2)
x = np.asmatrix(np.dstack([x1, x2]))
w = np.array([[1, 0], [1 / math.sqrt(2), 1 / math.sqrt(2)]])
ans = ICA.answer(w, x, 2)
a0, a1 = np.split(ans, 2, 1)
plt.plot(a0)
plt.plot(a1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
